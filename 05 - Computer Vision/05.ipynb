# %%
from PIL import Image
from imgtools import *

# %%
dir_path = r'.\img'
img_path = dir_path + '\sunflower01.jpg'

# %%
img = show_image(img_path)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x240>

# %%
img.size
# Out:
# (320, 240)

# %% [markdown]
# # XOAY ẢNH = ROTATE()

# %%
rotated_img = img.rotate(90)  # QUAY NGƯỢC CHIỀU KIM ĐỒNG HỒ
rotated_img
# nếu quay ảnh size vuông sẽ không bị mất pixel
# Out:
# <PIL.Image.Image image mode=RGB size=320x240>

# %% [markdown]
# # ĐẢO CHIỀU & XOAY ẢNH = TRANSPOSE()

# %% [raw]
# PIL.Image.FLIP_LEFT_RIGHT,
# PIL.Image.FLIP_TOP_BOTTOM,
# PIL.Image.ROTATE_90 ,
# PIL.Image.ROTATE_180,
# PIL.Image.ROTATE_270 or PIL.Image.TRANSPOSE.

# %%
transposed_img = img.transpose(Image.FLIP_LEFT_RIGHT)
transposed_img
# Out:
# <PIL.Image.Image image mode=RGB size=320x240>

# %%
transposed_img = img.transpose(Image.ROTATE_90)
transposed_img  # không bị mất pixel
# Out:
# <PIL.Image.Image image mode=RGB size=240x320>
