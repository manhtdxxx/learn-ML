# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow import keras
import tensorflow as tf
import h5py

# %% [markdown]
# # Dataset of Smiling Faces

# %%
train_happyDataset = h5py.File('train_happy.h5')
test_happyDataset = h5py.File('test_happy.h5')

for i in train_happyDataset.items():
    print(i)

print('-'*100)
for i in test_happyDataset.items():
    print(i)
# Out:
# ('list_classes', <HDF5 dataset "list_classes": shape (2,), type "<i8">)
# ('train_set_x', <HDF5 dataset "train_set_x": shape (600, 64, 64, 3), type "|u1">)
# ('train_set_y', <HDF5 dataset "train_set_y": shape (600,), type "<i8">)
# ----------------------------------------------------------------------------------------------------
# ('list_classes', <HDF5 dataset "list_classes": shape (2,), type "<i8">)
# ('test_set_x', <HDF5 dataset "test_set_x": shape (150, 64, 64, 3), type "|u1">)
# ('test_set_y', <HDF5 dataset "test_set_y": shape (150,), type "<i8">)

# %%
def load_dataset(trainDataset_path, testDataset_path):
    train_dataset = h5py.File(trainDataset_path)
    test_dataset = h5py.File(testDataset_path)
    
    train_X = np.array(train_dataset['train_set_x'])
    train_Y = np.array(train_dataset['train_set_y'])
    
    test_X = np.array(test_dataset['test_set_x'])
    test_Y = np.array(test_dataset['test_set_y'])

    classes = np.array(train_dataset['list_classes'])

    return train_X, train_Y, test_X, test_Y, classes

# %%
train_X, train_Y, test_X, test_Y, classes = load_dataset('train_happy.h5', 'test_happy.h5')
classes
# Out:
# array([0, 1], dtype=int64)

# %%
def visualize(X, Y, rows, cols):
    n_rows = rows
    n_cols = cols
    fig, axes = plt.subplots(n_rows, n_cols, figsize=(12, 8))
    
    random_indices = np.random.choice(X.shape[0], size = n_rows * n_cols, replace=False)
    
    for i in range(n_rows):
        for j in range(n_cols):
            idx = random_indices[i * n_cols + j]
            axes[i, j].imshow(X[idx])
            axes[i, j].set_title(f"Label: {Y[idx]}")
            axes[i, j].axis('off')
    
    plt.tight_layout()
    plt.show()

# %%
visualize(train_X, train_Y, rows=3, cols=5)

# %%
X_train = train_X / 255
X_test =  test_X / 255

Y_train = train_Y.reshape(-1, 1)
Y_test = test_Y.reshape(-1, 1)

print ("X_train shape: " + str(X_train.shape))
print ("Y_train shape: " + str(Y_train.shape))
print ("X_test shape: " + str(X_test.shape))
print ("Y_test shape: " + str(Y_test.shape))
# Out:
# X_train shape: (600, 64, 64, 3)
# Y_train shape: (600, 1)
# X_test shape: (150, 64, 64, 3)
# Y_test shape: (150, 1)

# %% [markdown]
# # Keras Sequential API
#
# ### https://www.tensorflow.org/guide/keras/sequential_model

# %%
sequential_model = keras.Sequential([
    # Conv Layers
    keras.layers.Input(shape=(64, 64, 3)),
    keras.layers.ZeroPadding2D(padding=(3,3)),
    keras.layers.Conv2D(filters=32, kernel_size=(7,7), strides=(1,1)),
    keras.layers.BatchNormalization(axis=3),  # channel
    keras.layers.ReLU(),
    keras.layers.MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='valid'),
    # Fully-Connected Layers
    keras.layers.Flatten(),
    keras.layers.Dense(units=1, activation='sigmoid')
])

# %%
sequential_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ zero_padding2d (ZeroPadding2D)       │ (None, 70, 70, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 64, 64, 32)          │           4,736 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 64, 64, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu (ReLU)                         │ (None, 64, 64, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 32, 32, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 32768)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │          32,769 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 37,633 (147.00 KB)
#  Trainable params: 37,569 (146.75 KB)
#  Non-trainable params: 64 (256.00 B)

# %%
sequential_model.compile(optimizer='adam',
                         loss='binary_crossentropy',
                         metrics=['accuracy'])

# %%
sequential_model.fit(X_train, Y_train, epochs=10, batch_size=16)
# Out:
# Epoch 1/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 6s 83ms/step - accuracy: 0.5902 - loss: 2.3736
# Epoch 2/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 87ms/step - accuracy: 0.8860 - loss: 0.2634
# Epoch 3/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - accuracy: 0.9247 - loss: 0.1859
# Epoch 4/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 95ms/step - accuracy: 0.9295 - loss: 0.1733
# Epoch 5/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 96ms/step - accuracy: 0.9739 - loss: 0.0780
# Epoch 6/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.9594 - loss: 0.0852
# Epoch 7/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 93ms/step - accuracy: 0.9577 - loss: 0.1167
# Epoch 8/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - accuracy: 0.9658 - loss: 0.1588
# Epoch 9/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - accuracy: 0.9523 - loss: 0.1267
# Epoch 10/10
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - accuracy: 0.9832 - loss: 0.0910

# %%
sequential_model.evaluate(X_test, Y_test)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9375 - loss: 0.1312
# [0.12253931909799576, 0.9466666579246521]

# %% [markdown]
# # Dataset of Hand Signs

# %%
train_X, train_Y, test_X, test_Y, classes = load_dataset('train_signs.h5', 'test_signs.h5')
classes
# Out:
# array([0, 1, 2, 3, 4, 5], dtype=int64)

# %%
visualize(train_X, train_Y, rows=3, cols=5)

# %%
X_train = train_X / 255
X_test =  test_X / 255

Y_train = keras.utils.to_categorical(train_Y, num_classes=6)
Y_test = keras.utils.to_categorical(test_Y, num_classes=6)

print ("X_train shape: " + str(X_train.shape))
print ("Y_train shape: " + str(Y_train.shape))
print ("X_test shape: " + str(X_test.shape))
print ("Y_test shape: " + str(Y_test.shape))
# Out:
# X_train shape: (1080, 64, 64, 3)
# Y_train shape: (1080, 6)
# X_test shape: (120, 64, 64, 3)
# Y_test shape: (120, 6)

# %% [markdown]
# # Keras Function API
#
# ### https://www.tensorflow.org/guide/keras/functional_api

# %%
def conv_model(input_shape):
    input = keras.Input(shape=input_shape)
    
    Z1 = keras.layers.Conv2D(filters=8, kernel_size=(4,4), strides=(1,1), padding='same')(input)
    A1 = keras.layers.ReLU()(Z1)
    P1 = keras.layers.MaxPooling2D(pool_size=(8,8), strides=(8,8), padding='same')(A1)

    Z2 = keras.layers.Conv2D(filters=16, kernel_size=(2,2), strides=(1,1), padding='same')(P1)
    A2 = keras.layers.ReLU()(Z2)
    P2 = keras.layers.MaxPooling2D(pool_size=(4,4), strides=(4,4), padding='same')(A2)

    F = keras.layers.Flatten()(P2)
    output = keras.layers.Dense(units=6, activation='softmax')(F)

    model = keras.models.Model(inputs=input, outputs=output)
    return model

# %%
functional_model = conv_model((64,64,3))
functional_model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)           │ (None, 64, 64, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 64, 64, 8)           │             392 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu_1 (ReLU)                       │ (None, 64, 64, 8)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 8, 8, 8)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 8, 8, 16)            │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu_2 (ReLU)                       │ (None, 8, 8, 16)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 2, 2, 16)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 6)                   │             390 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,310 (5.12 KB)
#  Trainable params: 1,310 (5.12 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
functional_model.compile(optimizer='adam',
                         loss='categorical_crossentropy',
                         metrics=['accuracy'])

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, Y_train)).batch(64)
test_dataset = tf.data.Dataset.from_tensor_slices((X_test, Y_test)).batch(64)

train_dataset, test_dataset
# Out:
# (<_BatchDataset element_spec=(TensorSpec(shape=(None, 64, 64, 3), dtype=tf.float64, name=None), TensorSpec(shape=(None, 6), dtype=tf.float64, name=None))>,
#  <_BatchDataset element_spec=(TensorSpec(shape=(None, 64, 64, 3), dtype=tf.float64, name=None), TensorSpec(shape=(None, 6), dtype=tf.float64, name=None))>)

# %%
training_process = functional_model.fit(train_dataset, epochs=100, validation_data=test_dataset)
# Out:
# Epoch 1/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 85ms/step - accuracy: 0.1497 - loss: 1.8187 - val_accuracy: 0.1917 - val_loss: 1.7950
# Epoch 2/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.1596 - loss: 1.7938 - val_accuracy: 0.2000 - val_loss: 1.7893
# Epoch 3/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 0.1776 - loss: 1.7884 - val_accuracy: 0.2000 - val_loss: 1.7864
# Epoch 4/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.1757 - loss: 1.7843 - val_accuracy: 0.2333 - val_loss: 1.7841
# Epoch 5/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.2056 - loss: 1.7806 - val_accuracy: 0.2000 - val_loss: 1.7818
# Epoch 6/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.2141 - loss: 1.7772 - val_accuracy: 0.1833 - val_loss: 1.7783
# Epoch 7/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.2199 - loss: 1.7728 - val_accuracy: 0.2083 - val_loss: 1.7743
# Epoch 8/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - accuracy: 0.2490 - loss: 1.7675 - val_accuracy: 0.2167 - val_loss: 1.7696
# Epoch 9/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 0.2744 - loss: 1.7609 - val_accuracy: 0.2167 - val_loss: 1.7628
# Epoch 10/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - accuracy: 0.3033 - loss: 1.7523 - val_accuracy: 0.2833 - val_loss: 1.7528
# Epoch 11/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - accuracy: 0.3374 - loss: 1.7405 - val_accuracy: 0.2917 - val_loss: 1.7418
# Epoch 12/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.3753 - loss: 1.7264 - val_accuracy: 0.3500 - val_loss: 1.7260
# Epoch 13/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.4118 - loss: 1.7060 - val_accuracy: 0.3500 - val_loss: 1.7045
# Epoch 14/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.4424 - loss: 1.6758 - val_accuracy: 0.3917 - val_loss: 1.6733
# Epoch 15/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.4636 - loss: 1.6322 - val_accuracy: 0.4417 - val_loss: 1.6334
# Epoch 16/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.5256 - loss: 1.5775 - val_accuracy: 0.4500 - val_loss: 1.5894
# Epoch 17/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.5346 - loss: 1.5230 - val_accuracy: 0.4333 - val_loss: 1.5393
# Epoch 18/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.5452 - loss: 1.4674 - val_accuracy: 0.4667 - val_loss: 1.4919
# Epoch 19/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.5760 - loss: 1.4130 - val_accuracy: 0.5000 - val_loss: 1.4428
# Epoch 20/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.5955 - loss: 1.3607 - val_accuracy: 0.5167 - val_loss: 1.3929
# Epoch 21/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.6004 - loss: 1.3094 - val_accuracy: 0.5500 - val_loss: 1.3440
# Epoch 22/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.6125 - loss: 1.2616 - val_accuracy: 0.5583 - val_loss: 1.2978
# Epoch 23/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.6031 - loss: 1.2161 - val_accuracy: 0.5750 - val_loss: 1.2553
# Epoch 24/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.6187 - loss: 1.1736 - val_accuracy: 0.5833 - val_loss: 1.2134
# Epoch 25/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.6273 - loss: 1.1347 - val_accuracy: 0.5833 - val_loss: 1.1714
# Epoch 26/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - accuracy: 0.6517 - loss: 1.0972 - val_accuracy: 0.6167 - val_loss: 1.1316
# Epoch 27/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - accuracy: 0.6685 - loss: 1.0625 - val_accuracy: 0.6417 - val_loss: 1.0928
# Epoch 28/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 115ms/step - accuracy: 0.6800 - loss: 1.0298 - val_accuracy: 0.6583 - val_loss: 1.0565
# Epoch 29/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 112ms/step - accuracy: 0.6905 - loss: 0.9989 - val_accuracy: 0.6667 - val_loss: 1.0212
# Epoch 30/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - accuracy: 0.7146 - loss: 0.9693 - val_accuracy: 0.6667 - val_loss: 0.9870
# Epoch 31/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.7190 - loss: 0.9410 - val_accuracy: 0.6667 - val_loss: 0.9549
# Epoch 32/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 0.7316 - loss: 0.9150 - val_accuracy: 0.6917 - val_loss: 0.9253
# Epoch 33/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.7341 - loss: 0.8898 - val_accuracy: 0.7000 - val_loss: 0.8985
# Epoch 34/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - accuracy: 0.7387 - loss: 0.8661 - val_accuracy: 0.7083 - val_loss: 0.8736
# Epoch 35/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.7411 - loss: 0.8435 - val_accuracy: 0.7250 - val_loss: 0.8498
# Epoch 36/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - accuracy: 0.7549 - loss: 0.8229 - val_accuracy: 0.7250 - val_loss: 0.8289
# Epoch 37/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - accuracy: 0.7569 - loss: 0.8035 - val_accuracy: 0.7250 - val_loss: 0.8098
# Epoch 38/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - accuracy: 0.7683 - loss: 0.7848 - val_accuracy: 0.7250 - val_loss: 0.7915
# Epoch 39/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - accuracy: 0.7750 - loss: 0.7670 - val_accuracy: 0.7167 - val_loss: 0.7750
# Epoch 40/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.7810 - loss: 0.7502 - val_accuracy: 0.7333 - val_loss: 0.7591
# Epoch 41/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - accuracy: 0.7845 - loss: 0.7338 - val_accuracy: 0.7333 - val_loss: 0.7451
# Epoch 42/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - accuracy: 0.7897 - loss: 0.7197 - val_accuracy: 0.7333 - val_loss: 0.7328
# Epoch 43/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 0.7944 - loss: 0.7056 - val_accuracy: 0.7333 - val_loss: 0.7209
# Epoch 44/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.7988 - loss: 0.6922 - val_accuracy: 0.7333 - val_loss: 0.7096
# Epoch 45/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.8054 - loss: 0.6793 - val_accuracy: 0.7333 - val_loss: 0.6988
# Epoch 46/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - accuracy: 0.8068 - loss: 0.6670 - val_accuracy: 0.7417 - val_loss: 0.6885
# Epoch 47/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 0.8061 - loss: 0.6554 - val_accuracy: 0.7417 - val_loss: 0.6789
# Epoch 48/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.8080 - loss: 0.6442 - val_accuracy: 0.7417 - val_loss: 0.6701
# Epoch 49/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.8097 - loss: 0.6336 - val_accuracy: 0.7500 - val_loss: 0.6618
# Epoch 50/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.8132 - loss: 0.6235 - val_accuracy: 0.7417 - val_loss: 0.6541
# Epoch 51/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.8147 - loss: 0.6144 - val_accuracy: 0.7417 - val_loss: 0.6464
# Epoch 52/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 0.8169 - loss: 0.6050 - val_accuracy: 0.7500 - val_loss: 0.6392
# Epoch 53/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 0.8169 - loss: 0.5961 - val_accuracy: 0.7500 - val_loss: 0.6328
# Epoch 54/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.8215 - loss: 0.5878 - val_accuracy: 0.7500 - val_loss: 0.6267
# Epoch 55/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - accuracy: 0.8240 - loss: 0.5801 - val_accuracy: 0.7583 - val_loss: 0.6207
# Epoch 56/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 0.8253 - loss: 0.5717 - val_accuracy: 0.7667 - val_loss: 0.6149
# Epoch 57/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - accuracy: 0.8271 - loss: 0.5639 - val_accuracy: 0.7750 - val_loss: 0.6096
# Epoch 58/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - accuracy: 0.8300 - loss: 0.5559 - val_accuracy: 0.7833 - val_loss: 0.6045
# Epoch 59/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - accuracy: 0.8337 - loss: 0.5486 - val_accuracy: 0.7833 - val_loss: 0.6001
# Epoch 60/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - accuracy: 0.8340 - loss: 0.5412 - val_accuracy: 0.7833 - val_loss: 0.5955
# Epoch 61/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - accuracy: 0.8333 - loss: 0.5342 - val_accuracy: 0.7833 - val_loss: 0.5915
# Epoch 62/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.8328 - loss: 0.5276 - val_accuracy: 0.8000 - val_loss: 0.5857
# Epoch 63/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.8382 - loss: 0.5197 - val_accuracy: 0.8000 - val_loss: 0.5834
# Epoch 64/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.8429 - loss: 0.5125 - val_accuracy: 0.8000 - val_loss: 0.5795
# Epoch 65/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - accuracy: 0.8420 - loss: 0.5056 - val_accuracy: 0.8000 - val_loss: 0.5764
# Epoch 66/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.8449 - loss: 0.4988 - val_accuracy: 0.8000 - val_loss: 0.5739
# Epoch 67/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 0.8458 - loss: 0.4922 - val_accuracy: 0.8000 - val_loss: 0.5710
# Epoch 68/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 94ms/step - accuracy: 0.8443 - loss: 0.4857 - val_accuracy: 0.8000 - val_loss: 0.5680
# Epoch 69/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - accuracy: 0.8469 - loss: 0.4796 - val_accuracy: 0.8000 - val_loss: 0.5651
# Epoch 70/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.8472 - loss: 0.4734 - val_accuracy: 0.8000 - val_loss: 0.5625
# Epoch 71/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.8531 - loss: 0.4679 - val_accuracy: 0.8000 - val_loss: 0.5601
# Epoch 72/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - accuracy: 0.8580 - loss: 0.4625 - val_accuracy: 0.8000 - val_loss: 0.5570
# Epoch 73/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - accuracy: 0.8583 - loss: 0.4574 - val_accuracy: 0.8000 - val_loss: 0.5542
# Epoch 74/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.8607 - loss: 0.4521 - val_accuracy: 0.8000 - val_loss: 0.5520
# Epoch 75/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - accuracy: 0.8617 - loss: 0.4472 - val_accuracy: 0.8083 - val_loss: 0.5496
# Epoch 76/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - accuracy: 0.8638 - loss: 0.4426 - val_accuracy: 0.8083 - val_loss: 0.5474
# Epoch 77/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - accuracy: 0.8638 - loss: 0.4382 - val_accuracy: 0.8083 - val_loss: 0.5453
# Epoch 78/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step - accuracy: 0.8673 - loss: 0.4335 - val_accuracy: 0.8083 - val_loss: 0.5432
# Epoch 79/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 98ms/step - accuracy: 0.8710 - loss: 0.4293 - val_accuracy: 0.8083 - val_loss: 0.5411
# Epoch 80/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - accuracy: 0.8710 - loss: 0.4253 - val_accuracy: 0.8167 - val_loss: 0.5395
# Epoch 81/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - accuracy: 0.8711 - loss: 0.4211 - val_accuracy: 0.8167 - val_loss: 0.5375
# Epoch 82/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - accuracy: 0.8710 - loss: 0.4171 - val_accuracy: 0.8167 - val_loss: 0.5359
# Epoch 83/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 0.8752 - loss: 0.4131 - val_accuracy: 0.8083 - val_loss: 0.5345
# Epoch 84/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.8752 - loss: 0.4095 - val_accuracy: 0.8083 - val_loss: 0.5328
# Epoch 85/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.8768 - loss: 0.4057 - val_accuracy: 0.8083 - val_loss: 0.5306
# Epoch 86/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - accuracy: 0.8768 - loss: 0.4021 - val_accuracy: 0.8083 - val_loss: 0.5292
# Epoch 87/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - accuracy: 0.8823 - loss: 0.3985 - val_accuracy: 0.8083 - val_loss: 0.5278
# Epoch 88/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.8831 - loss: 0.3953 - val_accuracy: 0.8083 - val_loss: 0.5257
# Epoch 89/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.8852 - loss: 0.3918 - val_accuracy: 0.8083 - val_loss: 0.5246
# Epoch 90/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.8837 - loss: 0.3887 - val_accuracy: 0.8083 - val_loss: 0.5231
# Epoch 91/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.8884 - loss: 0.3854 - val_accuracy: 0.8083 - val_loss: 0.5218
# Epoch 92/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.8908 - loss: 0.3827 - val_accuracy: 0.8083 - val_loss: 0.5201
# Epoch 93/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 0.8924 - loss: 0.3796 - val_accuracy: 0.8083 - val_loss: 0.5183
# Epoch 94/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.8924 - loss: 0.3765 - val_accuracy: 0.8083 - val_loss: 0.5173
# Epoch 95/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.8933 - loss: 0.3734 - val_accuracy: 0.8083 - val_loss: 0.5162
# Epoch 96/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.8935 - loss: 0.3708 - val_accuracy: 0.8083 - val_loss: 0.5149
# Epoch 97/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.8946 - loss: 0.3679 - val_accuracy: 0.8083 - val_loss: 0.5133
# Epoch 98/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.8946 - loss: 0.3648 - val_accuracy: 0.8083 - val_loss: 0.5124
# Epoch 99/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.8979 - loss: 0.3617 - val_accuracy: 0.8083 - val_loss: 0.5108
# Epoch 100/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.8980 - loss: 0.3590 - val_accuracy: 0.8083 - val_loss: 0.5094

# %%
metrics = training_process.history  # store accuracy and loss
df_metrics = pd.DataFrame(metrics)
df_metrics
# Out:
#     accuracy      loss  val_accuracy  val_loss
# 0   0.150000  1.806044      0.191667  1.794983
# 1   0.175926  1.791206      0.200000  1.789300
# 2   0.190741  1.786935      0.200000  1.786363
# 3   0.191667  1.783230      0.233333  1.784138
# 4   0.201852  1.779872      0.200000  1.781766
# ..       ...       ...           ...       ...
# 95  0.886111  0.370390      0.808333  0.514854
# 96  0.887963  0.367343      0.808333  0.513318
# 97  0.887963  0.364308      0.808333  0.512373
# 98  0.888889  0.361453      0.808333  0.510836
# 99  0.889815  0.358712      0.808333  0.509381
#
# [100 rows x 4 columns]

# %%
df_loss= df_metrics[['loss','val_loss']]
df_loss.plot(title='Model Loss',figsize=(6,4)).set(xlabel='Epoch', ylabel='Loss')
# Out:
# [Text(0.5, 0, 'Epoch'), Text(0, 0.5, 'Loss')]

# %%
df_acc = df_metrics[['accuracy','val_accuracy']]
df_acc.plot(title='Model Accuracy',figsize=(6,4)).set(xlabel='Epoch', ylabel='Accuracy')
# Out:
# [Text(0.5, 0, 'Epoch'), Text(0, 0.5, 'Accuracy')]
