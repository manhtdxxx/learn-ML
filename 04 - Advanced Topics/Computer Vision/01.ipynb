# %%
from PIL import Image

# %%
path = r'C:\Users\Admin\Documents\Learn_AI\05 - Computer Vision\img'

# %%
img_path = path + '\sunflower01.jpg'
img_path
# Out:
# 'C:\\Users\\Admin\\Documents\\Learn_AI\\05 - Computer Vision\\img\\sunflower01.jpg'

# %% [markdown]
# # ĐỌC ẢNH = OPEN()

# %%
img01 = Image.open(img_path)
img01
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x240>

# %% [markdown]
# # ĐỌC ẢNH = SHOW()

# %%
# show ảnh trên ứng dụng photo, not in this notebook
img01.show()

# %% [markdown]
# # ĐỊNH DẠNG ẢNH = FORMAT

# %%
'Định dạng ảng: ' + img01.format
# Out:
# 'Định dạng ảng: JPEG'

# %% [markdown]
# # KÍCH THƯỚC ẢNH = SIZE

# %%
print(type(img01.size))
print('Kích thước hình ảnh: ', img01.size)  # str KHÔNG + được với tuple
# Out:
# <class 'tuple'>
# Kích thước hình ảnh:  (320, 240)

# %% [markdown]
# # CHẾ ĐỘ MÀU = MODE

# %%
img01.mode
# Out:
# 'RGB'

# %% [markdown]
# # ĐÓNG ẢNH = CLOSE()

# %%
# đóng tập tin
#img01.close()

# %% [markdown]
# # LƯU ẢNH = SAVE()

# %%
# lưu ảnh và chuyển đổi format
new_img_path = path + '\sunflower04.PNG'
img01.save(new_img_path)

# %%
img02 = Image.open(new_img_path)
img02
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=320x240>

# %%
'Định dạng ảnh: ' + img02.format
# Out:
# 'Định dạng ảnh: PNG'
