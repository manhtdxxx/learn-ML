# %%
from PIL import Image
from imgtools import *

# %%
folder_path = r'C:\Users\Admin\Documents\Learn_AI\05 - Computer Vision\img'

# %% [markdown]
# # SHOW ALL IMAGES IN A FOLDER

# %%
images = listing_images(folder_path)
images
# Out:
# [<PIL.PngImagePlugin.PngImageFile image mode=RGB size=320x240>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x240>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x333>,
#  <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x240>]

# %%
for i in images:
    print(i.size)
    display(i)
# Out:
# (320, 240)
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=320x240>
# (320, 240)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x240>
# (500, 333)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x333>
# (320, 240)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x240>
