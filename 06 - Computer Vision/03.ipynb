# %%
from PIL import Image
from imgtools import *

# %%
dir_path = r'.\img'
img_path = dir_path + '\sunflower03.jpg'

# %%
img = show_image(img_path)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x240>

# %%
# Kích thước ban đầu
img.size, type(img.size)
# Out:
# ((320, 240), tuple)

# %% [markdown]
# # THAY ĐỔI KÍCH THƯỚC = RESIZE()

# %%
# Thay đổi kích thước
new_size = (100, 100)
new_img = img.resize(new_size)
new_img
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
new_img.save(dir_path + '\sunflower05.jpg')

# %% [markdown]
# # THAY ĐỔI KÍCH THƯỚC = THUMBNAIL()

# %%
# 1 function tương tự resize() nhma k tạo ảnh mới mà thay đổi size ảnh gốc
thumbnail_size = (200, 50)
img2 = img.thumbnail(thumbnail_size)

# %%
img2
# do thumbnail k tạo object mới

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=67x50>
