# %%
from imgtools import *
from PIL import Image
import matplotlib.pyplot as plt

# %%
path = '.\\img\\sunflower02.jpg'
img = Image.open(path)

# %%
img.size
# Out:
# (500, 333)

# %% [markdown]
# # ĐỌC ẢNH = IMSHOW()

# %%
plt.imshow(img)  # hiện thêm trục tọa độ
#plt.axis('on')  # nếu muốn tắt

# %% [markdown]
# # VẼ LÊN ẢNH = PLOT()

# %% [markdown]
# ##### colors : RED = 'r' , GREEN = 'g' , BLUE = 'b' , YELLOW = 'y' , CYAN = 'c' , MAGENTA = 'm' , BLACK = 'k' , WHITE = 'w'

# %% [markdown]
# ##### markers : POINT = '.' , CIRCLE = 'o' , SQUARE = 's' , STAR = '*' , PLUS = '+' , TICK = 'x'

# %% [markdown]
# ##### line styles : SOLID = '-' , DASHED = '--' , DOTTED = ':'

# %%
x = [100, 100, 400, 400]
y = [200, 300, 200, 300]
plt.imshow(img)
plt.plot(x, y, 'ro--')
